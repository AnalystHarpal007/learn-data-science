# %% [markdown]
# <a href="https://colab.research.google.com/github/AnalystHarpal007/learn-data-science/blob/main/Python_Tutorial_Day_1_Topic_Variables_and_Data_types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Basics — Topic 1: Variables & Data Types**

# %% [markdown]
# This is the foundation of programming.Python is a popular programming language. It was created by Guido van Rossum, and released in 1991.
#
# Every Python program starts with variables and data.

# %% [markdown]
# To check the Python version of the editor, you can find it by importing the sys module:

# %%
import sys

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %% [markdown]
# ## **What is a Variable?**
#
# A variable is a container used to store data.
#
# Think of it like a labeled box.
#
# Example:
#
# name stores a person's name
#
# age stores a person's age

# %% [markdown]
# **Rules for Python variables:**
#
# A variable name must start with a letter or the underscore character
#
# A variable name cannot start with a number
#
# A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
#
# Variable names are case-sensitive (age, Age and AGE are three different variables)
#
# A variable name cannot be any of the Python keywords.
#
# No spaces allowed

# %% [markdown]
# # **Python variable syntax**
#
# variable_name = value

# %%
name = "Rahul"
age = 25

# %%
print(name)
print(age)
# Out:
# Rahul
# 25

# %%
name = "Amit"
age = 22
height = 5.9
is_student = True

print(name)
print(age)
print(height)
print(is_student)
# Out:
# Amit
# 22
# 5.9
# True

# %% [markdown]
# # **Many Values to Multiple Variables**
#
# Python allows you to assign values to multiple variables in one line:

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
name, age, height = "Harpal", 30, 5.10
print(name)
print(age)
print(height)
# Out:
# Harpal
# 30
# 5.1

# %%
a, b, c = 10, 20, 30

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# 30

# %% [markdown]
# # **One Value to Multiple Variables**
#
# And you can assign the same value to multiple variables in one line:

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %% [markdown]
# # **Unpack a Collection**
#
# If you have a collection of values in a list, tuple etc. Python allows you to extract the values into variables. This is called unpacking.

# %%
fruits = ["apple", "banana", "cherry"]
x, y, z = fruits
print(x)
print(y)
print(z)
# Out:
# apple
# banana
# cherry

# %% [markdown]
# ## **Output Variables**
#
# The print() function is often used to output variables.

# %%
x = "Python is awesome"
print(x)
# Out:
# Python is awesome

# %% [markdown]
# In the print() function, you output multiple variables, separated by a comma:

# %%
x = "Python"
y = "is"
z = "awesome"
print(x, y, z)
# Out:
# Python is awesome

# %% [markdown]
# # **Python Data Types - Python supports multiple data types**
#
# | Data Type | Example | Description          |
# | --------- | ------- | -------------------- |
# | int       | 10      | Integer numbers      |
# | float     | 10.5    | Decimal numbers      |
# | str       | "Hello" | Text/String          |
# | bool      | True    | True/False           |
# | list      | [1,2,3] | Collection of items  |
# | tuple     | (1,2,3) | Immutable collection |
# | dict      | {"a":1} | Key-value pair       |

# %% [markdown]
# # **Understanding Each Data Type**

# %% [markdown]
# ## **1.Integer (int)**
#
# contains whole numbers.

# %%
age = 25
marks = 90

print(age)
print(marks)
# Out:
# 25
# 90

# %% [markdown]
# ## **2.Float (float)**
#
# Decimal numbers.

# %%
price = 99.99
temperature = 36.5

print(price)
print(temperature)
# Out:
# 99.99
# 36.5

# %% [markdown]
# ## **3.String (str)**
#
# Text data.

# %%
name = "Rahul"
city = 'Delhi'

print(name)
print(city)
# Out:
# Rahul
# Delhi

# %% [markdown]
# ## **4.Boolean (bool)**
#
# True or False values.

# %%
is_logged_in = True
is_admin = False

print(is_logged_in)
print(is_admin)
# Out:
# True
# False

# %% [markdown]
# # **Checking Data Type**
#
# Use type() function.

# %%
age = 25
print(type(age))
# Out:
# <class 'int'>

# %%
name = "Harpal"
print(name)
# Out:
# Harpal

# %%
print(type(name))
# Out:
# <class 'str'>

# %% [markdown]
# # **Type Conversion**
#
# Convert one data type to another.

# %% [markdown]
# **Integer to String**

# %%
age = 25

print(str(age))
# Out:
# 25

# %% [markdown]
# **String to Integer**

# %%
num = "100"

print(int(num))
# Out:
# 100

# %%
a = 35
print(float(a))
# Out:
# 35.0

# %% [markdown]
# # **User Input**
#
# Python allows taking input from users.

# %%
name = input("Enter your name: ")

print(name)
# Out:
# Enter your name: Harpal
# Harpal

# %%
age = int(input("Enter age: "))
# Out:
# Enter age: 30

# %% [markdown]
# **Important Note**
#
# input() always returns data as a string.

# %%
age = input("Enter age: ")

print(type(age))
# Out:
# Enter age: 55
# <class 'str'>

# %% [markdown]
# # **Mini Practice**

# %%
name = "Harpal"
city = "Bhopal"

print(name)
print(city)
# Out:
# Harpal
# Bhopal

# %%
price = 99.5
quantity = 3

total = price * quantity

print(total)
# Out:
# 298.5

# %% [markdown]
# # **Interview Questions**
#
# Q1. What is a variable?
#
# Answer - A variable is a container used to store data values.
#
# Q2. Difference between int and float?
#
# Answer - int stores whole numbers ,float stores decimal numbers
#
# Q3. What does type() do?
#
# Answer - It returns the data type of a variable.
#
#
# Q4. Why is input() dangerous sometimes?
#
# Answer - Because it always returns string data, which can cause type errors if not converted.

# %% [markdown]
# # **Mini Project**
#
# ## **Student Information System**
#
# Create a program that asks:
#
# student name
#
# age
#
# marks
#
# city
#
# Then print formatted output.

# %%
Student_Name = input("Enter Student Name: ")

Age = input("Enter Age: ")

Marks = input("Enter Marks: ")

City = input("Enter City: ")
# Out:
# Enter Student Name: Harpal
# Enter Age: 30
# Enter Marks: 100
# Enter City: Bhopal

# %% [markdown]
# # **Practice Challenge**
#
# Try predicting the output before running.

# %%
a = "10"
b = 20

print(a + str(b))
# Out:
# 1020
